# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshchobdar38/EDA-project/blob/main/(NITESH)Global_terrorism_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import** **libraries**

# %%
# Importing Libraries....
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load Dataset # read the dataset using pandas"read_csv"method
path ="/content/globalterrorismdb_0718dist.csv"
df= pd.read_csv(path,encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# First row of data
df.head(1)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
#
# [1 rows x 135 columns]

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# **Statistical** **values** **about** **the** **data**

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# **Data** **Cleaning**

# %%
# Data cleaning using drop function
df.drop('eventid',axis=1,inplace = True)

# %%
#checking first row of dataframe after data cleaning
df.head(1)
# Out:
#    iyear  imonth  iday approxdate  extended resolution  country  \
# 0   1970       7     2        NaN         0        NaN       58
#
#           country_txt  region                   region_txt  ... addnotes  \
# 0  Dominican Republic       2  Central America & Caribbean  ...      NaN
#
#   scite1  scite2  scite3  dbsource  INT_LOG INT_IDEO INT_MISC  INT_ANY  \
# 0    NaN     NaN     NaN      PGIS        0        0        0        0
#
#    related
# 0      NaN
#
# [1 rows x 134 columns]

# %%
#checking the shape of dataframe
df.shape
# Out:
# (181691, 134)

# %%
#checking null values of dataset
pd.DataFrame(df.isna().sum()).T
# Out:
#    iyear  imonth  iday  approxdate  extended  resolution  country  \
# 0      0       0     0      172452         0      179471        0
#
#    country_txt  region  region_txt  ...  addnotes  scite1  scite2  scite3  \
# 0            0       0           0  ...    153402   66191  104758  138175
#
#    dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0         0        0         0         0        0   156653
#
# [1 rows x 134 columns]

# %%
pd.DataFrame(df.isnull().sum()).T
# Out:
#    iyear  imonth  iday  approxdate  extended  resolution  country  \
# 0      0       0     0      172452         0      179471        0
#
#    country_txt  region  region_txt  ...  addnotes  scite1  scite2  scite3  \
# 0            0       0           0  ...    153402   66191  104758  138175
#
#    dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0         0        0         0         0        0   156653
#
# [1 rows x 134 columns]

# %%
#dropping values if a column have 50% of null value
thresold = len(df)*0.5
df = df.dropna(thresh= thresold,axis=1)

# %%
pd.DataFrame(df.isnull().sum()).T
# Out:
#    iyear  imonth  iday  extended  country  country_txt  region  region_txt  \
# 0      0       0     0         0        0            0       0           0
#
#    provstate  city  ...  nwoundus  nwoundte  property  ishostkid  scite1  \
# 0        421   434  ...     64702     69143         0        178   66191
#
#    dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# 0         0        0         0         0        0
#
# [1 rows x 57 columns]

# %%
df.shape  # checking shape
# Out:
# (181691, 57)

# %%
#covert columns into list 
list_col = df.columns.to_list()

# %%
#getting description of columns sepratly
for i in list_col:
  print(df[i].describe())
  print("-------------")
# Out:
# count    181691.000000
# mean       2002.638997
# std          13.259430
# min        1970.000000
# 25%        1991.000000
# 50%        2009.000000
# 75%        2014.000000
# max        2017.000000
# Name: iyear, dtype: float64
# -------------
# count    181691.000000
# mean          6.467277
# std           3.388303
# min           0.000000
# 25%           4.000000
# 50%           6.000000
# 75%           9.000000
# max          12.000000
# Name: imonth, dtype: float64
# -------------
# count    181691.000000
# mean         15.505644
# std           8.814045
# min           0.000000
# 25%           8.000000
# 50%          15.000000
# 75%          23.000000
# max          31.000000
# Name: iday, dtype: float64
# -------------
# count    181691.000000
# mean          0.045346
# std           0.208063
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: extended, dtype: float64
# -------------
# ...

# %%
#selecting column and storing float type elements in list
list_num_cols = df.select_dtypes(include = ['float']).columns.to_list()

# %%
for i in list_num_cols:   # filling na value with mean of column
  df[i].fillna(df[i].mean(),inplace = True)

# %%
#storing all the columns having object data types
list_str_cols = df.select_dtypes(include = ['object']).columns.to_list()

# %%
# replace all the na values for mode
for i in list_str_cols:
  df[i].fillna(df[i].mode(),inplace = True)

# %%
df.head(1) # again checking na value
# Out:
#    iyear  imonth  iday  extended  country         country_txt  region  \
# 0   1970       7     2         0       58  Dominican Republic       2
#
#                     region_txt provstate           city  ...  nwoundus  \
# 0  Central America & Caribbean   Baghdad  Santo Domingo  ...  0.038944
#
#    nwoundte  property  ishostkid  \
# 0  0.107163         0        0.0
#
#                                               scite1  dbsource  INT_LOG  \
# 0  Committee on Government Operations United Stat...      PGIS        0
#
#    INT_IDEO  INT_MISC  INT_ANY
# 0         0         0        0
#
# [1 rows x 57 columns]

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
corr =df.corr() # heatmap for given data
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# Chart - 1 visualization code plotting bar graph
sns.set_theme(style='whitegrid')
plt.figure(figsize =(24,9))
plt.ylim(0,2000,500)
plt.xticks(rotation=90)
sns.countplot(x=df['iyear'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='count'>

# %% [markdown]
# **Inferences:**

# %% [markdown]
# AS we can see mostly numbers of attacks in 2014 than in 2015 and 2016.

# %%
# diffrenciate the bar graph using function 'hue'.and finding duration of attacks
sns.set_theme(style ="whitegrid")
plt.figure(figsize=(22,10))
plt.ylim(0,20000,500)
plt.xticks(rotation =90)
sns.countplot(x=df['iyear'], hue = df['extended'])
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='count'>

# %% [markdown]
# This chart represents the how long terrorist attack is going on.

# %% [markdown]
# Mostly extended attacks were in 2014 and 2015.

# %%
#number of attacks according to months
sns.set_theme(style="whitegrid")
plt.figure(figsize=(22,10))
plt.ylim(0,20000,500)
plt.xticks(rotation=90)
plt.ylabel('Number of attacks')
plt.xlabel('Months')
sns.countplot(x=df['imonth'],palette ="Set3")
# Out:
# <AxesSubplot:xlabel='imonth', ylabel='count'>

# %% [markdown]
# Highest number of attacks were in  fifth(may) month.

# %% [markdown]
# this chart represnts the number of attacks according to months.

# %%
#diffrenciate the number of attacks in month chart
sns.set_theme(style="whitegrid")
plt.figure(figsize=(22,10))
plt.ylim(0,20000,400)
plt.xticks(rotation=90)
plt.ylabel('Number of attacks')
plt.xlabel('months')
sns.countplot(x=df['imonth'],hue = df['extended'])
# Out:
# <AxesSubplot:xlabel='imonth', ylabel='count'>

# %% [markdown]
# Lowest number of attacks were in 12th and 2nd and 9th month.

# %% [markdown]
# we can see number of attacks with respect of every month.

# %%
#diffrenciate number of attacks according to  day.
sns.set_theme(style=("whitegrid"))
plt.figure(figsize=(22,10))
plt.ylim(0,8000,500)
plt.xticks(rotation=90)
plt.ylabel('Number of attacks')
plt.xlabel('months')
sns.countplot(x=df['iday'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='iday', ylabel='count'>

# %% [markdown]
# Maximum number of attacks were on 15th date of a months.

# %%
#finding the highest number of attacks in a country
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14,40))
sns.countplot(y=df['country_txt'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='count', ylabel='country_txt'>

# %% [markdown]
# iraq than pakistan is the most sufferd country for terrorist attacks.

# %% [markdown]
# This graph shows india is at the fourth number which suffered with terrorist attacks.

# %%
#top 10 countries with terrorist attacks.
pd.DataFrame(df['country_txt'].value_counts()).head(10)
# Out:
#                 country_txt
# Iraq                  24636
# Pakistan              14368
# Afghanistan           12731
# India                 11960
# Colombia               8306
# Philippines            6908
# Peru                   6096
# El Salvador            5320
# United Kingdom         5235
# Turkey                 4292

# %%
# lets find out detailed analysis about india with terrorist attacks
India_df = df.loc[df['country_txt'] == 'India']

# %%
India_df.head(1)
# Out:
#       iyear  imonth  iday  extended  country country_txt  region  region_txt  \
# 1186   1972       2    22         0       92       India       6  South Asia
#
#      provstate       city  ...  nwoundus  nwoundte  property  ishostkid  \
# 1186     Delhi  New Delhi  ...       0.0       0.0         0        1.0
#
#      scite1      dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# 1186    NaN  Hijacking DB        1         1         1        1
#
# [1 rows x 57 columns]

# %%
#number of attacks in india with yaers
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
sns.countplot(x=India_df['iyear'],palette ="Set3")
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='count'>

# %% [markdown]
# Most number of attacks were in 2016 and 2017 in india.

# %%
#checking wheather attacks were suicide
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
sns.countplot(x= India_df['iyear'],hue = India_df['suicide'])
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='count'>

# %% [markdown]
# Most number of suicide attacks happen in india in 2015,
#  2016 and 2017.

# %%
# statewise number of attcks in india 
pd.DataFrame(India_df['provstate'].value_counts()).head(20)  # top 20 states with attacks
# Out:
#                    provstate
# Jammu and Kashmir       2454
# Assam                   1151
# Manipur                 1100
# Chhattisgarh             979
# Punjab                   949
# Jharkhand                887
# Bihar                    688
# West Bengal              650
# Odisha                   428
# Maharashtra              302
# Meghalaya                294
# Andhra Pradesh           251
# Orissa                   221
# Delhi                    208
# Uttar Pradesh            201
# Tamil Nadu               164
# Unknown                  157
# Tripura                  117
# Nagaland                 115
# Kerala                    98

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
sns.countplot(x= India_df['provstate'],palette ="Set3")
# Out:
# <AxesSubplot:xlabel='provstate', ylabel='count'>

# %% [markdown]
# Jammu and kashmir has the highest number of terrorist attacks.

# %%
#types of attacks in india
plt.figure(figsize=(22,9))
plt.xticks(rotation=90)
sns.countplot(x=India_df['attacktype1_txt'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='attacktype1_txt', ylabel='count'>

# %% [markdown]
# In india most of the terrorist attacks was done by explosion than by armed assult.

# %%
# terrorist target type in india 
plt.figure(figsize=(22,9))
plt.xticks(rotation=90)
sns.countplot(x= India_df['targtype1_txt'],palette = "Set3")
# Out:
# <AxesSubplot:xlabel='targtype1_txt', ylabel='count'>

# %% [markdown]
# private citizens and property are most favourite target for terrorist in india.

# %%
#groups name which were involved in terrorist attacks in india
pd.DataFrame(India_df['gname'].value_counts())
# Out:
#                                                 gname
# Unknown                                          4263
# Communist Party of India - Maoist (CPI-Maoist)   1877
# Maoists                                          1396
# Sikh Extremists                                   710
# United Liberation Front of Assam (ULFA)           357
# ...                                               ...
# Akhilesh Singh Gang                                 1
# Ananda Marga                                        1
# Al-Hamas Mujahideen                                 1
# Achik National Volunteer Council (ANVC)             1
# Ansar Ghazwat-ul-Hind                               1
#
# [301 rows x 1 columns]

# %% [markdown]
# mostly terrorist groups in india are unknowns after CPI is involved in terrorist activities.

# %%
#top 10 terrorist groups in india
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
sns.countplot(x= India_df['gname'].head(10))
# Out:
# <AxesSubplot:xlabel='gname', ylabel='count'>

# %%
#type of weapons use in terrorist attacks in india
pd.DataFrame(India_df['weaptype1_txt'].value_counts())
# Out:
#                                                     weaptype1_txt
# Explosives                                                   5030
# Firearms                                                     4530
# Incendiary                                                    930
# Unknown                                                       908
# Melee                                                         502
# Sabotage Equipment                                             32
# Chemical                                                       12
# Vehicle (not to include vehicle-borne explosive...              7
# Other                                                           7
# Fake Weapons                                                    2

# %% [markdown]
# Mostly used weapons are explosives in india for terrorist attacks.

# %%
#line graph for number of peoples killed in india with certain year
plt.figure(figsize=(12,8))
plt.xlim(1970,2020,5)
sns.lineplot(x = India_df['iyear'],y= India_df['nkill'])
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='nkill'>

# %% [markdown]
#  IN 1994 and 1995 there is big spike with number of deaths by terrorist attack in india.after its slightly decreasing.

# %%
#number of people wounded in terrorist attack in india
plt.figure(figsize =(14,8))
plt.xlim(1970,2020,5)
sns.lineplot(x= India_df['iyear'],y = India_df['nkill'])
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='nkill'>

# %% [markdown]
# highest number of wounded people in india by terrorist attack was in 1996 and 1997.

# %% [markdown]
# **JAMMU** **and** **Kashmir**

# %%
#explore data for Jammu and Kashmir
J_K = India_df.loc[India_df['provstate'] == 'Jammu and Kashmir']
J_K.head(1)
# Out:
#        iyear  imonth  iday  extended  country country_txt  region  region_txt  \
# 21744   1984       4    17         0       92       India       6  South Asia
#
#                provstate   city  ...  nwoundus  nwoundte  property  ishostkid  \
# 21744  Jammu and Kashmir  Bhela  ...  0.038944  0.107163         0        0.0
#
#       scite1  dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# 21744    NaN      PGIS        0         0         0        0
#
# [1 rows x 57 columns]

# %%
#ploting graph for jammu and kashmir terrorist aatacks
plt.figure(figsize=(22,8))
plt.xticks(rotation=90)
sns.countplot(x = J_K['iyear'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='count'>

# %% [markdown]
# The highest number of attacks were in Jammu and kashmir in 2017.

# %%
#terrorist groups name in j&k and attacks
plt.figure(figsize=(8,20))
plt.xticks(rotation=90)
sns.countplot(y=J_K['gname'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='count', ylabel='gname'>

# %% [markdown]
# Lashkar-e-taiybba is the mostly active terrorist group in Jammu and kashmir.

# %%
#type of attack in j&k
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
sns.countplot(x= J_K['attacktype1_txt'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='attacktype1_txt', ylabel='count'>

# %% [markdown]
# bombing explosion is the mostly used attack by terrorist in J&K.

# %%
#target type in J&K
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
sns.countplot(x= J_K['targtype1_txt'],palette="Set3")
# Out:
# <AxesSubplot:xlabel='targtype1_txt', ylabel='count'>

# %% [markdown]
# most of the target is police in jammu and kashmir.

# %%
#checking the wheather host is a kid or not
plt.figure(figsize=(10,12))
plt.xticks(rotation=90)
sns.countplot(x= J_K['ishostkid'],palette ="Set3")
# Out:
# <AxesSubplot:xlabel='ishostkid', ylabel='count'>

# %% [markdown]
# rarely there is only 200 incidents where kid is a host.

# %%
df_jk_year = pd.DataFrame(J_K.groupby(by = 'iyear').sum())

# %%
#number of peoples killed in j&k in terrorist attack
plt.figure(figsize =(12,7))
plt.xlim(1980,2020,5)
plt.plot(df_jk_year['nkill'])

# %% [markdown]
# IN 2001 and 2002 mostly people killed by terrorist attack in jammu anmd kashmir.

# %%
#number of people wounded in  jammu and kashmir
plt.figure(figsize=(12,7))
plt.xlim(1980,2020,5)
sns.lineplot(x = J_K['iyear'],y = J_K['nwound'])
# Out:
# <AxesSubplot:xlabel='iyear', ylabel='nwound'>

# %% [markdown]
# This graph shown highest number of people wounded in jammu and kashmir in 2003 and 2004.
